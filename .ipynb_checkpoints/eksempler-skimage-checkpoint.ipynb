# %%
from nbpictures import find_urls, get_picture_from_url, get_metadata_from_url, display_finds, load_picture
from IPython.display import HTML
import skimage
from skimage import feature
import pickle
import json
import io

# %%
r = find_urls('folkemuseum')

# %%
p = get_picture_from_url(r[1], width=500)

# %%
with io.BytesIO() as output:
    p.save(output, format='PNG')
    contents = output.getvalue()

# %%
(contents)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-60-a98830e8b638> in <module>()
# ----> 1 Image.open(contents)
#
# NameError: name 'Image' is not defined

# %%
fs = feature.blob_dog(p)
fs
# Out:
# array([[341.        ,  97.        ,  42.94967296],
#        [ 94.        ,  65.        ,  42.94967296]])

# %%
feature.blob_doh(p)
# Out:
# array([], shape=(0, 3), dtype=float64)

# %%
import matplotlib.pyplot as plt
import numpy as np
img = np.array(p)
fig, ax = plt.subplots()
ax.imshow(img)

# %%
from matplotlib.patches import Circle, Wedge, Polygon
fig, ax = plt.subplots()
for f in fs:
    print(f)
    c = Circle((f[0], f[1]), f[3], fill=False)
    ax.add_artist(c)
ax.imshow(img)
# Out:
# [341.          97.          42.94967296]
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-53-387d65d52d35> in <module>()
#       3 for f in fs:
#       4     print(f)
# ----> 5     c = Circle((f[0], f[1]), f[3], fill=False)
#       6     ax.add_artist(c)
#       7 ax.imshow(img)
#
# IndexError: index 3 is out of bounds for axis 0 with size 3

# %%
p
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=L size=339x451 at 0x19EE5735208>

# %%
get_metadata_from_url(r[1])
# Out:
# {'Tittel': 'Norsk folkemuseum',
#  'Dato': '01.01.1960 til 01.01.1961',
#  'Andre opplysninger': 'Motiv: prekestol, museum\nFotograf: ukjent',
#  'Utgiver': 'Mittet & Co. AS',
#  'Sted': 'Norge, Oslo, Oslo, Bygdøy,Oslo',
#  'Kilde for metadata': 'mavis.nb.no (/TitleWork/key/540185)',
#  'Medietype': 'bilder',
#  'Tilgang': 'Tilgang for alle',
#  'Varig lenke': '<a href="https://urn.nb.no/URN:NBN:no-nb_digifoto_20150121_00227_NB_MIT_FNR_19763" target="_blank">https://urn.nb.no/URN:NBN:no-nb_digifoto_20150121_00227_NB_MIT_FNR_19763</a>',
#  '': '<a href="https://www.nb.no/items/34a29e49f659ee4ed115bda2d4cd6c3a?manifest=https://api.nb.no/catalog/v1/iiif/34a29e49f659ee4ed115bda2d4cd6c3a/manifest" target="_blank"><img src="https://www.nb.no/content/uploads/2018/08/logo-iiif.png" alt="IIIF Drag-n-drop"></a>'}

# %%
get_picture_from_url(r[1])
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=L size=170x226 at 0x18BA407BB38>
