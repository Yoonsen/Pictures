# %%
import nbpictures as bp
from PIL import Image

# %%
pics = bp.super_search('nidarosdomen')

# %%
Image.open(bp.load_picture(bp.picture_url(pics, 5, 500)))
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=L size=339x451 at 0x22777B06CF8>
