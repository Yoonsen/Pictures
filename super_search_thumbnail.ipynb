# %%
import nbpictures as bp
from nbpictures import super_search, show_picture, load_picture, picture_urns, picture_url

# %matplotlib inline

# %%
from skimage import data, io, filters

# %%
pics = super_search('nidarosdomen')

# %%
p = show_picture(pics, 2, 500)

# %%
edges = filters.sobel(p)

# %%
io.imshow(edges)
# Out:
# D:\Anaconda3\lib\site-packages\skimage\io\_plugins\matplotlib_plugin.py:51: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   out_of_range_float = (np.issubdtype(image.dtype, np.float) and

# %%
show_picture(pics, 5, 500)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=L size=339x451 at 0x215C5B7CBE0>

# %%
show_picture(pics, 4, 700)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=L size=902x677 at 0x215C5BF60F0>

# %%
picts = super_search('vinter')

# %%
show_picture(picts, 0)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=L size=635x639 at 0x215C1DBA898>

# %%
show_picture(picts, 4)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=L size=635x644 at 0x215C5B6FD30>
